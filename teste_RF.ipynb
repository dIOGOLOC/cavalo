# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
from __future__ import print_function
from obspy.core import UTCDateTime
from obspy.core import read
import matplotlib.pyplot as plt

# %%
st = read('/home/diogo/RFTN/20111107223527/20111107223527/RFTN/R.*ABHZ*.1.0')
dt = UTCDateTime("1969-12-31T23:59:50")
tr = st.slice(dt, dt + 40)
tr.normalize(global_max=1)
tr.plot(type="relative", number_of_ticks=5, equal_scale_horizontal="True",color="red")
